# %% [markdown]
# *TASK 1*
# MAXIMUM PRODUCT OF TWO ELEMENTS IN AN ARRAY

# %%
def max_product(nums):
    max_product=0
    for i in range(len(nums)):
        for j in range(i,len(nums)):
            pro=(nums[i]-1)*(nums[j]-1)
            if i!=j and pro>max_product:
                max_product=pro
    return max_product

# %% [markdown]
# *TASK 2*
# COUNT NUMBER OF TEAMS

# %%
def no_of_teams(rating):
    count=0
    for i in range(len(rating)):
        for j in range(i,len(rating)):
            for k in range(j,len(rating)):
                if rating[i]<rating[j]<rating[k] or rating[i]>rating[j]>rating[k]:
                    count+=1
    return count

# %% [markdown]
# *TASK 3*
# NUMBER OF STUDENTS DOING HOMEWORK AT A GIVEN TIME

# %%
def student_doing_hw(start,end,query):
    count=0
    for i in range(len(start)):
        if start[i]<=query and query<=end[i]:
            count+=1
    return count

# %% [markdown]
# *TASK 4*
# NUMBER OF STEPS TO REDUCE A NUMBER TO ZERO

# %%
def steps(n):
    step_count=0
    while n>0:
        step_count+=1
        if n%2==0:
            n=n/2
        else:
            n=n-1
    return step_count
# Out:
# 8

# %% [markdown]
# *TASK 5*
# COUNTING BITS

# %%
def bits_count():
    ans=[0]*(n+1)
    for i in range(1,n+1):
            ans[i] = ans[i >> 1] + (i & 1)   
        return ans
